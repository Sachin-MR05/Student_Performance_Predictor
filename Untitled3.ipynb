# %% [markdown]
# # Training a model for the Student score Prediction

# %%
import pandas as pd ,numpy as np, sklearn as sk,matplotlib as plt,seaborn as sns,kagglehub
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %% [markdown]
# # Dataset
# [](https://)

# %%
path = kagglehub.dataset_download("spscientist/students-performance-in-exams")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/students-performance-in-exams

# %% [markdown]
# # Load Dataset

# %%
import os

files = os.listdir(path)
print("Files in the dataset directory:", files)

csv_file_path = os.path.join(path, files[0])

df = pd.read_csv(csv_file_path)
display(df.head())
# Out:
# Files in the dataset directory: ['StudentsPerformance.csv']
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
le = LabelEncoder()
df['gender'] = le.fit_transform(df['gender'])
df.gender = le.fit_transform(df['gender'])
display(df.head())
df['gender'].d_type ='float'
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0       0        group B           bachelor's degree      standard
# 1       0        group C                some college      standard
# 2       0        group B             master's degree      standard
# 3       1        group A          associate's degree  free/reduced
# 4       1        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Data Preprocessing

# %%
print(df.isnull().sum())
df = df.dropna()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
X = ['gender','race/ethnicity','parental level of education','lunch','test preparation course']
y = ['math score','reading score','writing score']

# %% [markdown]
# # StandardScaler

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2462607029.py in <cell line: 0>()
#       1 scaler = StandardScaler()
# ----> 2 X_scaled = scaler.fit_transform(X)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# --> 918             return self.fit(X, **fit_params).transform(X)
#     919         else:
# ...

# %%
print(df.dtypes)
# Out:
# gender                          int64
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object
